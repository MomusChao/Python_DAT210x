# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

# %%
matplotlib.style.use('ggplot')

# %%
df = pd.read_csv('concrete.csv',index_col=0)

# %%
df.columns
# Out:
# Index(['slag', 'ash', 'water', 'superplastic', 'coarseagg', 'fineagg', 'age',
#        'strength'],
#       dtype='object')

# %%
df.columns = []

# %%
df.plot.scatter(x='water',y='strength')
plt.suptitle('Water vs Strength')
plt.xlabel('Water')
plt.ylabel('strength')
plt.show()
