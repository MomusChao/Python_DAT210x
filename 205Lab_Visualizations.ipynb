# %% [markdown]
# # Lab Assignment 1

# %%
## seeds data set
# https://archive.ics.uci.edu/ml/datasets/seeds

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Loads the seeds dataset
df = pd.read_csv("wheat.data", index_col = "id")
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %%
# slicing
s1 = df[["area", "perimeter"]]
s1.head()
# Out:
#      area  perimeter
# id
# 0   15.26      14.84
# 1   14.88      14.57
# 2   14.29      14.09
# 3   13.84      13.94
# 4   16.14      14.99

# %%
# slicing
s2 = df[["groove", "asymmetry"]]
s2.head()
# Out:
#     groove  asymmetry
# id
# 0    5.220      2.221
# 1    4.956      1.018
# 2    4.825      2.699
# 3    4.805      2.259
# 4    5.175      1.355

# %%
# Create a histogram (alpha=0.75)
s1.plot.hist(title="Slice 1", bins=20, alpha=0.75)
s2.plot.hist(title="Slice 2", alpha=0.75)

# %% [markdown]
# # Lab Assignment 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Loads the seeds dataset
df = pd.read_csv("wheat.data", index_col = "id")
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %%
# Create a 2d scatter
df.plot.scatter(x = "area", y="perimeter")

# %%
# Create a 2d scatter
df.plot.scatter(x="groove", y="asymmetry")

# %%
# Create a 2d scatter
df.plot.scatter(x="compactness", y="width")

# %% [markdown]
# # Lab Assignment 3

# %%
# %matplotlib notebook

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
# Loads the seeds dataset
df = pd.read_csv("wheat.data", index_col = "id")
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %%
# Graph a 3D scatter plot
fig = plt.figure()

ax = fig.add_subplot(111, projection = '3d')
ax.set_xlabel("area")
ax.set_ylabel("perimeter")
ax.set_zlabel("asymmetry")

ax.scatter(df.area, df.perimeter, df.asymmetry, c='red')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Graph a 3D scatter plot
fig = plt.figure()

ax = fig.add_subplot(111, projection = "3d")
ax.set_xlabel("width")
ax.set_ylabel("groove")
ax.set_zlabel("length")

ax.scatter(df.width, df.groove, df.length, c='green', marker = '.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Lab Assignment 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from pandas.tools.plotting import parallel_coordinates

# %%
# Loads the seeds dataset
df = pd.read_csv("wheat.data", index_col = "id")
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %%
# drop data
df.drop(["area", "perimeter"], axis=1, inplace=True)
df.head()
# Out:
#     compactness  length  width  asymmetry  groove wheat_type
# id
# 0        0.8710   5.763  3.312      2.221   5.220       kama
# 1        0.8811   5.554  3.333      1.018   4.956       kama
# 2        0.9050   5.291  3.337      2.699   4.825       kama
# 3        0.8955   5.324  3.379      2.259   4.805       kama
# 4        0.9034   5.658  3.562      1.355   5.175       kama

# %%
plt.figure()
parallel_coordinates(df, 'wheat_type', alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Lab Assignment 5

# %%
from sklearn.datasets import load_iris
from pandas.tools.plotting import andrews_curves
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Look pretty
matplotlib.style.use('ggplot')

# %%
# Loads the seeds dataset
df = pd.read_csv("wheat.data", index_col = "id")
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %%
# drop data
df.drop(["area", "perimeter"], axis=1, inplace=True)
df.head()
# Out:
#     compactness  length  width  asymmetry  groove wheat_type
# id
# 0        0.8710   5.763  3.312      2.221   5.220       kama
# 1        0.8811   5.554  3.333      1.018   4.956       kama
# 2        0.9050   5.291  3.337      2.699   4.825       kama
# 3        0.8955   5.324  3.379      2.259   4.805       kama
# 4        0.9034   5.658  3.562      1.355   5.175       kama

# %%
# Andrews Curves
plt.figure()
andrews_curves(df, 'wheat_type', alpha = 0.4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Lab Assignment 6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# Loads the seeds dataset
df = pd.read_csv("wheat.data", index_col = "id")
df.head()
# Out:
#      area  perimeter  compactness  length  width  asymmetry  groove wheat_type
# id
# 0   15.26      14.84       0.8710   5.763  3.312      2.221   5.220       kama
# 1   14.88      14.57       0.8811   5.554  3.333      1.018   4.956       kama
# 2   14.29      14.09       0.9050   5.291  3.337      2.699   4.825       kama
# 3   13.84      13.94       0.8955   5.324  3.379      2.259   4.805       kama
# 4   16.14      14.99       0.9034   5.658  3.562      1.355   5.175       kama

# %% [markdown]
# i don't need to drop 'id'

# %%
# Graph the correlation matrix
df.corr()
# Out:
#                  area  perimeter  compactness    length     width  asymmetry  \
# area         1.000000   0.994341     0.600312  0.645418  0.801616  -0.205876
# perimeter    0.994341   1.000000     0.520544  0.657490  0.783188  -0.196360
# compactness  0.600312   0.520544     1.000000  0.360060  0.756165  -0.315668
# length       0.645418   0.657490     0.360060  1.000000  0.197228  -0.102325
# width        0.801616   0.783188     0.756165  0.197228  1.000000  -0.249378
# asymmetry   -0.205876  -0.196360    -0.315668 -0.102325 -0.249378   1.000000
# groove       0.786096   0.813256     0.236184  0.669887  0.619865  -0.039248
#
#                groove
# area         0.786096
# perimeter    0.813256
# compactness  0.236184
# length       0.669887
# width        0.619865
# asymmetry   -0.039248
# groove       1.000000

# %%
# Graph the correlation matrix using imshow or matshow
plt.matshow(df.corr(), cmap=plt.cm.Blues, interpolation = "nearest")
plt.colorbar()
tick_marks = [i for i in range(len(df.columns))]
plt.xticks(tick_marks, df.columns, rotation="vertical")
plt.yticks(tick_marks, df.columns)
# Out:
# <img src="data:image/png;base64,..." width="664.8">
# ([<matplotlib.axis.YTick at 0x1f81db23240>,
# ...
#  <a list of 8 Text yticklabel objects>)
